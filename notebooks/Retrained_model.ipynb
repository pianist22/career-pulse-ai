# %%
# The 1st Cell Implementation.........

# %% [markdown]
# # Digital Resume Screener: Simplified Flow
#
# ---
#
# ## 1. Setting Up the Screener (Loading the Brain and Tools)
#
# | Option | Description |
# | :--- | :--- |
# | **A. The Toolbox** | The code first identifies where all the necessary tools are stored: the **Model's Brain** (the actual classification logic), the **Dictionary** (the list of possible job categories), and the **Test Resumes**. |
# | **B. Hiring the Brain** | It loads the specific, trained **Digital Brain** (a DistilBERT model) from its storage location. This brain knows how to read text and assign it to a category. |
# | **C. Hiring the Translator** | It loads the **Translator** (the Tokenizer). This tool's only job is to turn normal English text from the resumes into a special, numerical language that the Digital Brain can actually understand. |
# | **D. Output** | We now have the **Digital Brain** and the **Translator**, ready to work. |
#
# ---
#
# ## 2. Understanding the Categories (Setting the Grading Key)
#
# | Option | Description |
# | :--- | :--- |
# | **A. Fetching the Key** | The code looks at the Digital Brain to see if it already has a list that says: `0 = 'Engineer'`, `1 = 'Sales'`, `2 = 'HR'`. This is the master list of possible job categories. |
# | **B. Correcting the Key** | If the list is generic (like `0 = 'LABEL_0'`), the code quickly checks the original training data file to rebuild the correct, meaningful list of categories. |
# | **C. Output** | We get a finalized **Category Key** (e.g., `id2label`), ensuring the output will be meaningful job titles, not just numbers. |
#
# ---
#
# ## 3. Testing and Grading the Resumes (Running the Inference)
#
# | Option | Description |
# | :--- | :--- |
# | **A. Getting the Test Stack** | The code pulls out a stack of **Test Resumes** from the designated test file. (It might grab a small sample, like 200, for a quick check). It also removes any resumes that don't have a correct answer (true job category) assigned yet. |
# | **B. Processing in Piles** | It splits the Test Resumes into small, manageable piles (batches of 64) for faster processing. |
# | **C. Brain at Work** | For each pile: the **Translator** converts the text into numbers, and the **Digital Brain** processes those numbers, outputting a **score** for *every single possible job category*. |
# | **D. Final Decision** | These scores are converted into **Confidence Percentages** (e.g., 90% chance it's 'Engineer'). The highest percentage becomes the **Final Predicted Job Category**. |
# | **E. Output** | A detailed list of results (`pred_df`) is generated for each resume, showing the **True Job Category**, the **Predicted Job Category**, the **Confidence**, and the **Top 3** most likely categories. |
#
# ---
#
# ## 4. Evaluating the Screener's Performance (Generating the Report Card)
#
# | Option | Description |
# | :--- | :--- |
# | **A. Overall Accuracy** | The code calculates the overall scores: **Accuracy** (Did the top choice match the true job category?) and **Top-3 Accuracy** (Was the true job category among the top 3 choices?). |
# | **B. Detailed Class Report** | It creates a full **Report Card** (using the `classification_report`) that details how well the brain did for *each individual job category* (e.g., it was great at identifying 'Engineers' but poor at identifying 'HR'). |
# | **C. Output** | Two easy-to-read tables: **Overall Metrics** (e.g., 92% Accuracy) and a **Per-Category Report** (how well it did on 'Engineer', 'Sales', etc.). |

# %%
import numpy as np, pandas as pd, torch
from torch.nn.functional import softmax
from transformers import AutoTokenizer, AutoModelForSequenceClassification, AutoConfig
from sklearn.metrics import classification_report

FINAL_DIR = "artifacts/distilbert_resume_cls_final"
TEST_PARQUET = "../data/processed/classification_test.parquet"
TRAIN_PARQUET = "../data/processed/classification_train.parquet"

def load_inference_bundle(final_dir=FINAL_DIR):
    tok = AutoTokenizer.from_pretrained(final_dir)                               # tokenizer for inference [web:527]
    cfg = AutoConfig.from_pretrained(final_dir)                                   # config carries id2label/label2id [web:343]
    model = AutoModelForSequenceClassification.from_pretrained(final_dir, config=cfg).eval()  # model weights [web:349]
    return tok, model

def resolve_id2label(model, train_parquet=TRAIN_PARQUET):
    # Prefer saved mapping; if generic LABEL_x, rebuild from training labels (sorted)
    if getattr(model.config, "id2label", None) and len(model.config.id2label) > 0:
        id2label = {int(k): v for k, v in dict(model.config.id2label).items()}   # ensure int keys [web:343]
        if all(str(v).startswith("LABEL_") for v in id2label.values()):
            df = pd.read_parquet(train_parquet)
            labels = sorted(df["label"].dropna().unique().tolist())
            id2label = {i: labels[i] for i in range(len(labels))}
    else:
        df = pd.read_parquet(train_parquet)
        labels = sorted(df["label"].dropna().unique().tolist())
        id2label = {i: labels[i] for i in range(len(labels))}
    return id2label

def infer_predictions_df(sample_n=50, batch_size=64, max_length=256):
    tok, model = load_inference_bundle()                                          # load tokenizer/model [web:349][web:527]
    id2label = resolve_id2label(model)                                            # consistent label names [web:343]
    test_df = pd.read_parquet(TEST_PARQUET)                                       # load held‑out data [web:442]
    test_df = test_df[test_df["label"].notna()].copy()                            # drop missing labels [web:442]
    # Optional sub‑sample for quicker view
    if sample_n and sample_n < len(test_df):
        test_df = test_df.sample(sample_n, random_state=42)
    # Batched inference
    logits_all = []
    texts = test_df["text"].tolist()
    for i in range(0, len(texts), batch_size):
        batch = texts[i:i+batch_size]
        enc = tok(batch, truncation=True, padding=True, max_length=max_length, return_tensors="pt")
        with torch.no_grad():
            logits_all.append(model(**enc).logits.cpu())
    if not logits_all:
        return pd.DataFrame(), pd.DataFrame()
    logits = torch.cat(logits_all, dim=0)
    probs = softmax(logits, dim=1).numpy()
    pred_ids = probs.argmax(axis=1)
    pred_labels = [id2label[int(i)] for i in pred_ids]
    true_labels = test_df["label"].astype(str).str.strip().tolist()
    # Assemble per‑row predictions
    rows = []
    for i, text in enumerate(texts[:len(pred_labels)]):
        idxs = probs[i].argsort()[-3:][::-1]
        top3 = [(id2label[int(j)], float(probs[i][j])) for j in idxs]
        rows.append({
            "text_snippet": (text or "")[:200].replace("\n", " ") + ("..." if text and len(text) > 200 else ""),
            "true_label": true_labels[i],
            "pred_label": pred_labels[i],
            "confidence": float(probs[i].max()),
            "top3": top3
        })
    pred_df = pd.DataFrame(rows)
    return pred_df, (probs, true_labels, pred_labels, id2label)

def metrics_df_from_outputs(probs, true_labels, pred_labels, id2label):
    # Accuracy and top‑k on strings
    acc = float(np.mean([p == t for p, t in zip(pred_labels, true_labels)]))
    def topk_hit(i, k):
        idxs = probs[i].argsort()[-k:][::-1]
        return true_labels[i] in [id2label[int(j)] for j in idxs]
    top3 = float(np.mean([topk_hit(i, 3) for i in range(len(true_labels))])) if len(true_labels) else 0.0
    top5 = float(np.mean([topk_hit(i, 5) for i in range(len(true_labels))])) if len(true_labels) else 0.0
    # Classification report to DataFrame
    report = classification_report(true_labels, pred_labels, zero_division=0, output_dict=True)  # sklearn report [web:442]
    report_df = pd.DataFrame(report).T.reset_index().rename(columns={"index": "label_or_avg"})
    overall_df = pd.DataFrame([{"metric": "accuracy", "value": round(acc, 4)},
                               {"metric": "top3", "value": round(top3, 4)},
                               {"metric": "top5", "value": round(top5, 4)}])
    return overall_df, report_df

# Run once and display clean DataFrames
pred_df, bundle = infer_predictions_df(sample_n=200)                               # increase sample_n for more rows [web:349]
probs, y_true_lbls, y_pred_lbls, id2label = bundle
overall_df, report_df = metrics_df_from_outputs(probs, y_true_lbls, y_pred_lbls, id2label)

# Show in notebook (or save to CSV)
print("Overall metrics:\n", overall_df)
print("\nPer‑class report (head):\n", report_df.head(12))
print("\nPredictions (head):\n", pred_df.head(12))
# pred_df.to_csv("artifacts/predictions_sample.csv", index=False)
# overall_df.to_csv("artifacts/metrics_overall.csv", index=False)
# report_df.to_csv("artifacts/metrics_report.csv", index=False)
# Out:
# Overall metrics:
#       metric  value
# 0  accuracy  0.905
# 1      top3  0.955
# 2      top5  0.970
#
# Per‑class report (head):
#                   label_or_avg  precision    recall  f1-score  support
# 0                  Accountant   1.000000  1.000000  1.000000      8.0
# 1                    Advocate   0.800000  1.000000  0.888889      4.0
# 2                 Agriculture   0.750000  0.600000  0.666667      5.0
# 3                     Apparel   0.600000  1.000000  0.750000      3.0
# 4                Architecture   0.833333  1.000000  0.909091      5.0
# 5                        Arts   0.857143  1.000000  0.923077      6.0
# 6                  Automobile   0.750000  0.500000  0.600000      6.0
# 7                    Aviation   1.000000  1.000000  1.000000      5.0
# 8                         BPO   0.666667  0.500000  0.571429      4.0
# 9                     Banking   1.000000  1.000000  1.000000      5.0
# 10  Building and Construction   1.000000  0.714286  0.833333      7.0
# ...

# %%
# Now , The 2nd Cell Implementation.........

# %% [markdown]
# # Digital Resume Screener: Simplified Flow (Continued)
#
# ---
#
# ## 1. Setting Up the Screener (Hiring the Tools)
#
# | Option | Description |
# | :--- | :--- |
# | **A. Defining Locations** | The code first locks in the addresses for the three key files: the **Trained Brain** (the classification model), the **Training Resumes** (the original key for job titles), and the **Test Resumes** (the papers to grade). |
# | **B. Loading Components** | It immediately loads the **Digital Brain** (Model), the **Translator** (Tokenizer), and the **Config/Settings** (Config) from the saved file location. The Brain is put in 'evaluation mode' to start grading. |
# | **C. Output** | The **Digital Brain**, **Translator**, and **Settings** are loaded and ready. |
#
# ---
#
# ## 2. Setting the Grading Key (Ensuring Meaningful Job Titles)
#
# | Option | Description |
# | :--- | :--- |
# | **A. Check Saved Key** | The code first tries to pull the list of job categories (e.g., `0 = 'Engineer'`, `1 = 'Sales'`) directly from the **Settings** file. |
# | **B. Correct or Rebuild Key** | If the key is missing or has generic names (like 'LABEL\_0'), the code immediately loads the **Training Resumes** file. It looks at all the actual job titles in that file, sorts them alphabetically, and rebuilds the final, correct **Category Key**. |
# | **C. Output** | A finalized dictionary (`id2label`) ensures the final output will be meaningful job titles, not just numbers. |
#
# ---
#
# ## 3. Preparing Data and Grading (Inference)
#
# | Option | Description |
# | :--- | :--- |
# | **A. Preparing the Test Stack** | The code loads the **Test Resumes** file, removing any resumes that don't have a correct answer (true job category) assigned. It keeps the list of correct answers (`y_true_labels`) separate. |
# | **B. Batch Processing** | The resume texts are processed in small **piles** (batches of 64) for speed. For each pile, the **Translator** converts the text to numbers, which are fed into the **Digital Brain**. |
# | **C. Generating Scores** | The Brain outputs a **score** (logit) for every job category. These scores are converted into **Confidence Percentages** (`probs`). |
# | **D. Final Prediction** | The job category with the highest confidence percentage is chosen as the **Predicted Job Category** (`y_pred_labels`). |
# | **E. Output** | A list of **Confidence Percentages** for all categories (`probs`) and a list of the **Predicted Job Categories** (`y_pred_labels`). |
#
# ---
#
# ## 4. Generating the Report Card (Metrics and Results)
#
# | Option | Description |
# | :--- | :--- |
# | **A. Overall Performance** | The code calculates how often the Brain got the top answer right (**Accuracy**) and how often the correct answer was at least in the top 3 and top 5 choices (**Top-3/Top-5**). |
# | **B. Printing Summary** | It prints a brief summary of these overall accuracy numbers. |
# | **C. Full Report Card** | It generates and prints the **Classification Report**, which gives a detailed grade (Precision, Recall, F1) for *each individual job category*. |
# | **D. Sample Results** | A small table is created (only the first 20 resumes) showing the text snippet, the **True Label**, the **Predicted Label**, the **Confidence**, and the **Top 3** predictions, which is then printed to the console. |
# | **E. Output** | Printed text showing the **Overall Accuracy**, the **Per-Category Report**, and a **Sample of 20 Detailed Predictions**. |

# %%
# eval_inference_string_labels_fixed.py
# Use saved model; rebuild id2label if config has generic "LABEL_x" names.

import numpy as np, pandas as pd, torch
from torch.nn.functional import softmax
from transformers import AutoTokenizer, AutoModelForSequenceClassification, AutoConfig
from sklearn.metrics import classification_report

FINAL_DIR = "artifacts/distilbert_resume_cls_final"
TEST_PARQUET = "../data/processed/classification_test.parquet"
TRAIN_PARQUET = "../data/processed/classification_train.parquet"

# 1) Load model/tokenizer/config
tok = AutoTokenizer.from_pretrained(FINAL_DIR)
cfg = AutoConfig.from_pretrained(FINAL_DIR)
model = AutoModelForSequenceClassification.from_pretrained(FINAL_DIR, config=cfg).eval()

# 2) Build id2label
def load_id2label_from_config(cfg):
    if getattr(cfg, "id2label", None) and len(cfg.id2label) > 0:
        return {int(k): v for k, v in dict(cfg.id2label).items()}
    return None

id2label = load_id2label_from_config(cfg)

# If mapping is missing or generic (e.g., all start with "LABEL_"), rebuild from training labels
def is_generic(mapping):
    return mapping and all(str(v).startswith("LABEL_") for v in mapping.values())

if (id2label is None) or is_generic(id2label):
    train_df = pd.read_parquet(TRAIN_PARQUET)
    labels = sorted(train_df["label"].dropna().unique().tolist())  # LabelEncoder uses sorted order
    id2label = {i: labels[i] for i in range(len(labels))}
label2id = {v: k for k, v in id2label.items()}

# 3) Load and clean test data
test_df = pd.read_parquet(TEST_PARQUET)
test_df = test_df[test_df["label"].notna()].copy()
y_true_labels = test_df["label"].astype(str).str.strip().tolist()

# 4) Batched inference
def predict_logits(texts, batch_size=64, max_length=256):
    outs = []
    for i in range(0, len(texts), batch_size):
        batch = texts[i:i+batch_size].tolist()
        enc = tok(batch, truncation=True, padding=True, max_length=max_length, return_tensors="pt")
        with torch.no_grad():
            outs.append(model(**enc).logits.cpu())
    return torch.cat(outs, dim=0) if outs else torch.empty((0, len(id2label)))

logits = predict_logits(test_df["text"], batch_size=64, max_length=256)
num_model_labels = logits.shape[1]
if num_model_labels != len(id2label):
    raise ValueError(f"Label count mismatch: model has {num_model_labels} outputs but id2label has {len(id2label)} names.")

probs = softmax(logits, dim=1).numpy()
pred_ids = probs.argmax(axis=1)
y_pred_labels = [id2label[int(i)] for i in pred_ids]

# 5) Metrics
acc = float(np.mean([p == t for p, t in zip(y_pred_labels, y_true_labels)]))
def topk_hit(i, k=3):
    idxs = probs[i].argsort()[-k:][::-1]
    return y_true_labels[i] in [id2label[int(j)] for j in idxs]
top3 = float(np.mean([topk_hit(i, 3) for i in range(len(y_true_labels))]))
top5 = float(np.mean([topk_hit(i, 5) for i in range(len(y_true_labels))]))
print({"accuracy": round(acc, 4), "top3": round(top3, 4), "top5": round(top5, 4)})

# 6) Classification report (string labels on both sides)
print(classification_report(y_true_labels, y_pred_labels, zero_division=0))

# 7) Compact predictions DataFrame
rows = []
sample_n = min(20, len(test_df))
for i in range(sample_n):
    idxs = probs[i].argsort()[-3:][::-1]
    rows.append({
        "text_snippet": (test_df["text"].iloc[i] or "")[:200].replace("\n", " ") + ("..." if len(test_df["text"].iloc[i]) > 200 else ""),
        "true_label": y_true_labels[i],
        "pred_label": y_pred_labels[i],
        "confidence": float(probs[i].max()),
        "top3": [(id2label[int(j)], float(probs[i][j])) for j in idxs]
    })
pred_df = pd.DataFrame(rows)
print("\nSample predictions (first 20):")
print(pred_df.to_string(index=False))
# Out:
# {'accuracy': 0.885, 'top3': 0.9459, 'top5': 0.9638}
#                            precision    recall  f1-score   support
#
#                Accountant       0.93      0.96      0.94        70
#                  Advocate       0.92      0.95      0.93        58
#               Agriculture       0.84      0.88      0.86        59
#                   Apparel       0.90      0.83      0.86        64
#              Architecture       0.92      0.71      0.80        69
#                      Arts       0.91      0.92      0.92        66
#                Automobile       0.77      0.55      0.64        62
#                  Aviation       0.99      0.97      0.98        68
#                       BPO       0.63      0.66      0.64        41
#                   Banking       0.92      0.94      0.93        63
#                Blockchain       1.00      1.00      1.00         9
# Building and Construction       0.83      0.86      0.84        69
# ...

# %% [markdown]
# # Code Comparison: `1st Cell Vs 2nd Cell`
#
# | Feature | Cell 1 (Original, Function-based) | Cell 2 (Second, Linear Script) |
# | :--- | :--- | :--- |
# | **Workflow Style** | **Structured/Modular** (Functions call other functions). | **Linear/Sequential** (Steps executed one after the other). |
# | **Main Execution** | The workflow is contained in the `infer_predictions_df()` and `metrics_df_from_outputs()` functions, which are called at the end. | The core logic runs sequentially in the main body of the script (steps 1 through 7). |
# | **Setup & Loading** | Uses a separate function, `load_inference_bundle()`, to load the model and tokenizer. | Loads the model, tokenizer, and config **directly** at the start of the script. |
# | **Label Logic** | Uses a large, unified function, `resolve_id2label()`, to handle label mapping. | Splits the logic into a small helper function (`load_id2label_from_config`) and a **clear `if/else` block** for rebuilding the mapping. |
# | **Inference Logic** | Inference is run *inside* the large `infer_predictions_df()` function. | The batched prediction loop is separated into a clear, reusable function, `predict_logits()`. |
# | **Output DataFrames** | The prediction and metrics DataFrames are assembled *inside* their respective functions. | The metrics are calculated and printed immediately; a small DataFrame is created at the end for the **sample (first 20) predictions**. |
# | **Overall Goal** | To define reusable functions for inference and evaluation. | To execute a complete, step-by-step evaluation script. |
